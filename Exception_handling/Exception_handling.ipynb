# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmidurga0940-collab/Python/blob/main/Exception_handling/Exception_handling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exception handling is a programming concept used to manage error or unexpected conditions that occure during the exicution of a programme .it alles the programe to continue running of failgracefully instead of crashing .
#
# # Use Exception Handling?
#  - To prevent the entire program from crashing due to runtime errors.
#
#  - To provide informative error messages.
#
#  - To allow recovery or alternative execution paths.
# #common terms
#
#  - Exception: An error that occurs during program execution.
#
#  - Try block: Code that might throw an exception.
#
#  - Except block: Code that runs if an exception occurs.
#
#  - Finally block: Code that always runs, whether an exception occurred or not.
#
#  - Raise: Manually trigger an exception.

# %% [markdown]
# # **What are Errors?**
#  - Errors are issues in the code that prevent it from executing successfully.
#
#
#  **Types of Errors**
#   - 1. Synatx Errors
#   - 2. Runtime Erros
#   - 3. Logical Errors

# %% [markdown]
#   **1. Syntax Errors**
#    - Occur when the code vilates python's syntax rules.
#    - Detetcted before execution.
#    - Example: Missing colons, unmatched parentheses.
#
#     _   missing a colon at the end of the if statement
#
#     if 5>3
#     print("this willl cause a syntax error")
#
#     Error Message :
#      Syntax Error: invalid syntax
#
#
#   **The python interpreter cannot undersstand the code because of incorrect syntax, such as missing colons, unmatched parentheses. or msissplled keywords.**

# %%
if 5>3
  print("this will cause syntax error")
# Out:
#   File "/tmp/ipython-input-3802157884.py", line 1
#     if 5>3
#           ^
# SyntaxError: expected ':'

# %% [markdown]
# **2. Runtime Errors**
#
#  - Occur during program execution
#  - Example: Division by zero , accessing undefined variable
#
#
#
#
#  Example Code
#  Division by zero :
#
#
#  x=1=/0
#  print(x)
#
#
#  Error Message :
#  zero Division Error : division by zero
#
#
#  **The program syntax is correct, but the operation fails at runtime(eg, dividing by zero, accessing an undefined variable , or file not found).**

# %%
x=1/0
print(x)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipython-input-223042854.py in <cell line: 0>()
# ----> 1 x=1/0
#       2 print(x)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# **3. Logical Errors**
#  - The program runs but gives incorrect results due to logic flaws,
#  - Example: incorrect formula or condition.
#
#
#
#  incorrect formula for calculating the area of a rectangle
#
# length =5
#
# width= 10
#
# area = length +width # should be length * width
#
# print("Area;",area)
#
# ouput:
# Area :15
#
#
#
#
#
#
# **The program runs successsfully but, the result is wrong because of a mustake in the logic of formula**

# %%
try:
  num=int(input("Enter a nuber:"))
  result=10/num
except ZeroDivisionError:
  print("cannot divide by zero!")
except ValueError:
  print("please enter a valid number!")
else:
  print("Division successful! Result:",result)
finally:
  print("This block always runs.")
# Out:
# Enter a nuber:5
# Division successful! Result: 2.0
# This block always runs.

# %%
length=8
width=5
area=length+width
print("Area:",area)
# Out:
# Area: 13

# %% [markdown]
# ## The Try-Except Block
#
# **Basis Structrue:**
#
# (try:
#   code that might raise an exception
#
#   except Esception Type:
#     code to handle the exception)
#
#
# Example code:
#
# try:
#
# x= int (input("Eneter a number:"))
# y=10/x
#
# exceptzeroDivisionError:
#
# print("Cannot divide by zero")

# %%
try:
  a=int (input("Enter the number:"))
  b=10/a
  print(b)
except ZeroDivisionError:
  print("Cannot divde by zero")
# Out:
# Enter the number:0
# Cannot divde by zero

# %%
try:
  x=int(input("Enter a number:"))
  z=10/x
except ZeroDivisionError as e:
  print(e)
# Out:
# Enter a number:0
# division by zero

# %%
try:
  print(f)
except:
  print("Error occured")
# Out:
# Error occured

# %%
print(n)
print("Hello world")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2883073416.py in <cell line: 0>()
# ----> 1 print(n)
#       2 print("Hello world")
#
# NameError: name 'n' is not defined

# %%
try:
  print(a)
except:
  print("Error occured")
print("hello world")
# Out:
# Error occured
# hello world

# %% [markdown]
# `If except we do, The error will not show thats the use of the try-exept block`
# `And it will not stop the code it just skip the error`

# %% [markdown]
# Else and Finally Block

# %%
try:
  result=10/2
except ZeroDivisionError:
  print("Error")
else:
  print("Result:",result)
# Out:
# Result: 5.0

# %% [markdown]
# Finally

# %%
try:
  file_=open("data.txt","r")
except FileNotFoundError:
  print("File not found!")
finally:
  print("End of program.")
# Out:
# File not found!
# End of program.

# %%
#overflow error
import math
print(math.exp(1000))
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# /tmp/ipython-input-790541606.py in <cell line: 0>()
#       1 import math
# ----> 2 print(math.exp(1000))
#
# OverflowError: math range error

# %%
#Attribute error
obj=82
obj.append(92)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-1360398098.py in <cell line: 0>()
#       1 obj=82
# ----> 2 obj.append(92)
#
# AttributeError: 'int' object has no attribute 'append'

# %%
#key error
data={"name":"toofan"}
print(data["age"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-2151212596.py in <cell line: 0>()
#       1 #key error
#       2 data={"name":"toofan"}
# ----> 3 print(data["age"])
#
# KeyError: 'age'

# %%
#index error
my_list=[1,2,3,4,5,6]
print(my_list[8])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-2724200845.py in <cell line: 0>()
#       1 #index error
#       2 my_list=[1,2,3,4,5,6]
# ----> 3 print(my_list[8])
#
# IndexError: list index out of range

# %%
#value error
print(int("hello"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2498892550.py in <cell line: 0>()
#       1 #value error
# ----> 2 print(int("hello"))
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
#Type error
print("5"+5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3957014166.py in <cell line: 0>()
#       1 #Type error
# ----> 2 print("5"+5)
#
# TypeError: can only concatenate str (not "int") to str

# %%
#FileNotFoundError
open("nonexist_file.txt")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-3384827231.py in <cell line: 0>()
#       1 #FileNotFoundError
# ----> 2 open("nonexist_file.txt")
#
# FileNotFoundError: [Errno 2] No such file or directory: 'nonexist_file.txt'

# %% [markdown]
# Raise exception

# %%
age=int(input("Enter your age:"))
if age<0:
  raise ValueError("Age cant be negative")
else:
  print(f"your age is{age}")
print("No try except")
# Out:
# Enter your age:15
# your age is15
# No try except

# %%
try:
  age=int(input("Enter your age:"))
  if age<0:
    raise ValueError("Age cannot be negative")
  else:
    print(f"Your age is {age}")
except ValueError as i:
  print(i)
print("try except finished")
# Out:
# Enter your age:18
# Your age is 18
# try except finished

# %% [markdown]
# Custom Exceptions

# %%
class InvalidAgeException(Exception):

 number=17
try:
  input_num=int(input("Emter a number:"))
  if input_num<number:
    raise InvalidAgeException
  else:
   print("Eligible to vote")
except InvalidAgeException:
  print("Exception Occured:Invalid age")
# Out:
# Emter a number:16
# Exception Occured:Invalid age

# %% [markdown]
# Write a Python function safe_divide(a, b) that attempts to divide two numbers, a and b. Implement exception handling to manage the following scenarios:
#
# 1.ZeroDivisionError: If b is zero, print "Error: Division by zero is not allowed."
#
# 2.ValueError: If either a or b is not a valid number (e.g., a string), print "Error: Please enter valid numbers."
#
# 3.General Exception: For any other unforeseen errors, print "An unexpected error occurred."

# %%
a=int(input("Enter the number:"))
b=int(input("Enter the number:"))
def safe_divide (a,b):
  try:
   result=a/b
   print(result)
  except ZeroDivisionError:
    print("Division by zero is not allowed")
  except ValueError:
    print("Please enter a valid number")
  except Exception:
    print("An unexpected error occurred")
  finally:
    print("safe divide")
safe_divide(a,b)
# Out:
# Enter the number:12
# Enter the number:6
# 2.0
# safe divide

# %% [markdown]
# Write a program to handle FileNotFoundError while opening a file.

# %%
try:
  file=open("laksh.txt","r")
except FileNotFoundError:
  print("file not found")
finally:
  print("End of program")
# Out:
# file not found
# End of program

# %% [markdown]
# Write a program using try–except–finally block.

# %%
try:
  file=open("laksh.txt","r")
except FileNotFoundError:
  print("File not opened")
finally:
  print("Successfully opened.")
# Out:
# File not opened
# Successfully opened.

# %% [markdown]
# Write a program using try–except–else block.

# %%
try:
  result=12/6
except ZeroDivisionError:
  print("Error")
else:
  print("Result:",result)
# Out:
# Result: 2.0

# %% [markdown]
# Write a program to demonstrate runtime error handling using try and except.

# %%
try:
    a = int(input("Enter a number: "))
    b = int(input("Enter another number: "))
    result = a / b
    print("Result =", result)
except:
    print("Runtime error occurred")
# Out:
# Enter a number: 25
# Enter another number: 5
# Result = 5.0

# %% [markdown]
# Write a program to handle division by zero using exception handling.

# %%
try:
  a=int(input("Enter a number"))
  b=12/a
except ZeroDivisionError as i:
  print(i)
# Out:
# Enter a number0
# division by zero
