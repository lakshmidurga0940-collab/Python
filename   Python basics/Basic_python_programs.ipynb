# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshmidurga0940-collab/Python/blob/main/%20%20Python%20basics/Basic_python_programs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Python Programs

# %%
print("hello world")

# %%
x=2
print(x)

# %%
a=2
b=4
sum=a+b
print(sum)

# %%
#multiplication
j=42
l=32
z=j*l
print(z)
print(type(z))

# %% [markdown]
# # string

# %%
x=1
x="hello"
print(x[0])

# %%
x="hello python"
print(len(x))
print("hello" not in x)

# %%
x="hello python"
y=123
z=1.23
a=True
print(type(x,y,z,a))

# %%
x=13456
z=12345
z=int(x)
a=z+x
print(a)

# %%
xyz="hy my name is python"
print(xyz[2:10])

# %%
word="hello python"
print(word[-5:-2])

# %%
a="Hello,World!"
print(a.strip("hello world"))

# %%
a="hello,word!"
print(a.replace("H","j"))

# %%
a="Hello,World"
print(a.split(","))

# %%
word="hello python"
print(word.upper())

# %%
age=36
txt="MY name is john,I am"+age
print(txt)

# %%
age=36
txt="My name is john,and I am{}"
print(txt.format(age))

# %%
txt="We are the so called\"vikings\"from the north."
print(txt)

# %% [markdown]
# # bool

# %%
print(10==10)
print(10<8)
print(10==100)

# %%
x=200
print(isinstance(x,int))

# %% [markdown]
# # operators

# %% [markdown]
# ## arithematic operators

# %%
x=5
z=9
y=x+z
print(y)

# %%
x=7
z=5
r=x-z
print(r)

# %%
x=5
r=9
c=x*r
print(c)

# %%
x=5
y=10
z=x/y
print(z)

# %%
x=8
y=4
z=x//y
print(z)

# %%
x=9
y=3
z=x%y
print(z)

# %% [markdown]
# ## assignment operator

# %%
x=5
x+=5
print(x)

# %%
x=5
x-=2
print(x)

# %%
x=2
x*=3
print(x)

# %%
x=6
x/=3
print(x)

# %%
x=6
x//=5
print(x)

# %%
x=11
x%=3
print(x)

# %%
x=11
x&=3
print(x)

# %% [markdown]
# # logical operator

# %%
x=5;y=6
x>1 and y<10

# %%
x=5;y=7
x>6 or y<11

# %%
x=5
not x>1

# %% [markdown]
# # identity operator

# %%
x=5;y=6
x is y

# %%
x=5;y=7
x is not y

# %% [markdown]
# # membership operator

# %%
nums =[1,2,3,4,5,9]
9 in nums

# %%
nums=[11,22,33,44,55,66]
55 not in nums

# %% [markdown]
# # bitwise operator

# %%
x=5
y=9
z=x&y
print(z)

# %%
x=5
y=10
z=x/y
print(z)

# %%
x=5
y=10
z=x^y
print(z)

# %% [markdown]
# #List

# %%
Fruits=["apple","grape","kiwi","cherry"]
print(Fruits)

# %%
Fruits=["kiwi","apple","litchi","mango","grape"]
print(Fruits[2])

# %%
Fruits=["kiwi","apple","litchi","mango","grape"]
print(Fruits[-3])

# %%
veg=["carrot","beans","cabbage","tomato","potato"]
print(veg[2:4])

# %%
veg=["carrot","beans","cabbage","tomato","potato"]
print(veg[2:])

# %%
veg=["carrot","beans","cabbage","tomato","potato"]
print(veg[:4])

# %%
fruits=["litchi","grape","orange","mango"]
fruits.insert(3,"apple")
print(fruits)

# %%
fruits=["litchi","grape","orange","mango"]
fruits.append("apple")
print(fruits)

# %%
Fruits=["apple","banana","mango"]
fruits2=["litchi","grape"]
Fruits.extend(fruits2)
print(Fruits)

# %%
Fruits=["apple","banana","cherry"]
Fruits.remove("apple")
print(Fruits)

# %%
Fruits=["apple","banana","cherry"]
Fruits.pop(2)
print(fruits)

# %%
fruits=["apple","grape","mango"]
del fruits[2]
print(fruits)

# %%
fruits=["apple","grape","litchi"]
fruits.clear()
print(fruits)

# %%
fruits=["litchi","grape","watermelon","mango"]
myfruits=fruits.copy()
print(myfruits)

# %% [markdown]
# # Tuple

# %%
Fruits=["apple","banana","cherry"]
print(len(fruits))

# %%
Fruits=["apple","banana","cherry"]
print(type(fruits))

# %%
Fruits= ("apple", "banana", "cherry")
print(Fruits[1])

# %%
Fruits= ("apple", "banana", "cherry")
print(Fruits[-1])

# %%
x = ("apple","kiwi","grape","mango")
y = list(x)
y[1] = "watermelon"
x = tuple(y)
print(x)

# %%
fruits = ("apple", "banana", "cherry")
(green, yellow, red) = fruits
print(red)
print(green)
print(yellow)

# %% [markdown]
# # Set

# %%
fruits= {"apple", "banana", "cherry"}
fruits.add("orange")
print(fruits)

# %%
fruits = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]
fruits.update(mylist)
print(fruits)

# %%
fruits = {"apple","banana","cherry"}
fruits.remove("cherry")
print(fruits)

# %%
fruits = {"apple","banana","cherry"}
fruits.discard("cherry")
print(fruits)

# %%
fruits = {"apple","banana","grape"}
fruits.clear()
print(fruits)

# %%
fruits= {"apple", "banana", "cherry"}
x = fruits.pop()
print(x)
print(fruits)

# %%
set1 = {"a","b","c","d"}
set2 = {"1","2","3"}
set3 = set1.union(set2)
print(set3)

# %%
set1 = {"a","b","c"}
set2 = {1,2,3}
set1.update(set2)
print(set1)

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.intersection_update(y)
print(x)

# %%
x = {"apple","grape","cherry"}
y = {"google","microsoft","apple"}
z = x.intersection(y)
print(z)

# %%
x = {"apple", "banana", "cherry"}
y = {"google", "microsoft", "apple"}
x.symmetric_difference_update(y)
print(x)

# %%
x = {"apple","banana","cherry"}
y = {"google","microsoft","apple"}
z = x.symmetric_difference(y)
print(z)

# %% [markdown]
# # Frozenset

# %%
nu= (1,2,3,4,5,6,7,8,9)
fnum= frozenset(nu)
print("frozenset objects is:",fnum)

# %% [markdown]
# # Dictionaries

# %%
cars= {
    "brand":"BNW",
    "model":"2nd series",
    "year":2005
}
print(cars)

# %%
car= {
    "brand":"BNW",
    "model":"mustang",
    "year":1964
}
x=car.values()
print(x)
car["year"]=2020
print(x)

# %%
car={
    "brand":"Ford",
    "model":"mustang",
    "year":1964
}
car.update({"year":2020})
print(car)

# %%
friends={
    "child1":{
    "name":"arun",
    "year":2000
    },
    "child2":{
        "name":"gowtham",
        "year":2001
    },
    "child3":{
    "name":"lachu",
    "year":2007
    }
}
print(friends)

# %%
car={
    "brand":"ford",
    "model":"mustang",
    "year":2001
}
car.pop('year')
print(car)

# %% [markdown]
# # Conditional statement

# %%
a=55
b=200
if b > a:
  print("b is greater than a")

# %%
a=33
b=33
if b > a:
  print("b is greater than a")
elif a==b:
  print("a and b are equal")

# %%
a=25
b=200
print("A") if a > b else print("B")

# %%
a=330
b=330
print("A") if a > b else print("=")if a==b else print("B")

# %%
a=200
b=33
c=500
if a > b and c > a:
  print("Both conditions are True")

# %%
a=200
b=33
c=400
if a > b or a > c:
  print("Atleast one of the condition is True")

# %%
x=41
if x > 10:
  print("Above ten,")
if x > 20:
  print("and also above 20!")
else:
 print("but not above 20.")

# %%
a=20
b=30
if a>b:
  pass

# %%
a=int(input("enter the number"))
print(a)

# %%
a=int(input("enter the number"))
b=int(input("enter the second number"))
if a>b:
  print("a is greater")
else:
  print("b is greater")

# %%
x=int(input("enter the number"))
if x>90:
  print("A+")
elif x>80:
  print("A")
elif x>70:
  print("B+")
elif x>60:
  print("c")
elif x>50:
  print("D")
else:
  print("fail")

# %% [markdown]
# Ask the user to enter a number.
# Use if to check if the number is positive.

# %%
a=int(input("enter the number"))
if a<0:
   print("Number is negative")
else:
   print("Number is positive")

# %% [markdown]
# Ask the user for their age.
# Use if to check if the user is 18 or older, and print a message saying they can vote.

# %%
a=int(input("enter the number"))
if a<18:
  print("Not eligible for vote")
else:
  print("Eligible for vote")

# %% [markdown]
# Looping Statement

# %%
i=0
while i<4:
  i+=1
  print(i)

# %%
i=25
while i>17:
  i-=1
  print(i)

# %%
i=0
while i<7:
  i+=1
  print(i)
  break

# %%
a='loop in python'
i-=0
while i<len(a):
  i+=1
print('value of i:',i)

# %%
i=0
a='loops in python'
while i<len(a):
 if a[i]=='e' or a[i]=='s':
  i+=1
  continue
 print('Current Letter:',a[i])
 i+=1

# %%
i=0
while i<4:
  i+=1
  print(i)
else: #Executed because no break in for
  print("No Break\n")

# %%
i=0
while i<4:
  i+=1
  print(i)
  break
else:#Not excuted as there is a break
  print("No Break")

# %% [markdown]
# For loop

# %%
#Iterating over a list
print("List iteration")
l=["hello","for","python"]
for i in l:
  print(i)

# %%
#Iterating over a tuple
print("\nTuble iteration")
t=("hello","for","python")
for i in t:
  print(t)

# %%
#Iterating over dictionary
print("\nDictionary Iteration")
d=dict()
d['xyz']=123
d['abc']=345
for i in d:
  print("%s%d"%(i,d[i]))

# %% [markdown]
# Loop control statement

# %%
for x in 'python developer':
  if x=='e' or x=='o':
    continue
  print('Current Letter:',x)

# %%
for x in 'python developer':
  if x=='e' or x=='o':
    break
  print('Current Letter:',x)

# %%
for x in 'python developer':
  pass
print('Current Letter:',x)

# %% [markdown]
# Range function

# %%
#show range()basics
#printing a numer
for i in range(10):
  print(i,end=" ")
print()

# %%
#using range for iteration
l=[10,20,30,40,50]
for i in range(len(l)):
  print(l[i],end=" ")
print()

# %%
#performing sum of natural
# number
Sum = 0
for i in range(1,11):
  Sum=Sum+i
print("sum of first to natural number:",Sum)

# %% [markdown]
# For else loop

# %%
for i in range(1,4):
  print(i)
  break
else:#Not executed as there is a break
  print("No Break")

# %%
adj=["red","big","tasty"]
fruits=["apple","cherry","strawberry"]
for x in adj:
  for y in fruits:
    print(x,y)

# %% [markdown]
# Write a program to print "Hello, Python!"

# %%
print("Hello,Python!")

# %% [markdown]
# Write a program to add two numbers.

# %%
x=int(input("enter the number"))
y=int(input("enter the number"))
sum=x+y
print(sum)

# %% [markdown]
# Write a program to print numbers from 1 to 10 using a for loop.

# %%
i=0
while i<10:
  i+=1
  print(i)

# %% [markdown]
# Write a program to print even numbers from 2 to 20.

# %%
i=0
while i<20:
  i+=2
  print(i)

# %% [markdown]
# Write a program to print each character in the word "Python" using a loop.

# %%
for i in "python":
  print(i)

# %% [markdown]
# Write a program to print the multiplication table of 5.

# %%
for i in range(1,10):
  print(i*5)

# %% [markdown]
# Write a program to print numbers from 10 to 1 in reverse order.

# %%
i=11
while i>1:
  i-=1
  print(i)

# %% [markdown]
# Write a program to print numbers from 1 to 5 using a while loop.

# %%
i=0
while i<5:
  i+=1
  print(i)

# %% [markdown]
# Write a program to count how many numbers between 1–20 are divisible by 3.

# %%
for i in range(1,20):
  if i%3==0:
    print(i)

# %% [markdown]
# Write a program to stop the loop if the number equals 7 (use break).

# %%
i=0
while i<10:
  i+=7
  print(i)
  break

# %% [markdown]
# Write a program to print "Even" or "Odd" for numbers from 1–10

# %%
for i in range(1,10):
  if i%2==0:
    print(i,"even")
  else:
      print(i,"odd")

# %% [markdown]
# Write a program that skips printing number 5 (use continue).

# %%
for x in (1,10):
  if x==5:
    continue
  print(x)

# %% [markdown]
# write a program to find factorial of a number

# %%
n=2
f=1
for i in range (1,n+1):
  f = f*i
print(f)

# %% [markdown]
# Print the sum of all numbers from 1 to 50 using a for loop

# %%
total = 0
for i in range(1, 51):
    total += i
print("Sum =", total)

# %% [markdown]
# Print multiplication table for numbers from 1 to 10

# %%
for i in range(1,10):
  print(i*10)

# %% [markdown]
# print prime numbers 1 to 50

# %%
num = int(input("Enter the number:"))
for i in range(2,num):
  if num % i ==0:
    print("not a prime number")
    break
else:
    print("prime")

# %% [markdown]
# Reverse a string using a for loop.

# %%
word = "python"
reverse = " "
for i in word:
  reverse=i+reverse

# %% [markdown]
# Count vowels in a given string.

# %%
text="hello world"
count=0
a="aeiouAEIOU"
for i in text:
  if i in a:
    count+=1
print("Number of vowels:", count)
# Out:
# Number of vowels: 3

# %% [markdown]
# Print the largest number from a list using a for loop.

# %%
a=[5,6,7,11,8,9]
largest=0
for i in a:
    if i > largest:
        largest = i
print("Largest:",largest)

# %% [markdown]
# # Python Functions

# %%
def hello():
  print("welcome to ipcs")
hello()
# Out:
# welcome to ipcs

# %% [markdown]
# # Calling a Function

# %%
def haiii():
  print("hlo lachu")
haiii()
# Out:
# hlo lachu

# %% [markdown]
# # Arguments of a Function

# %%
def evenorodd(x):
  if(x%2==0):
    print("even")
  else:
    print("odd")
evenorodd(6)
evenorodd(7)
# Out:
# even
# odd

# %% [markdown]
# # Default Argument

# %%
def myfun(x,y=60):
  print("x:",x)
  print("y:",y)
myfun(10)
# Out:
# x: 10
# y: 60

# %%
def students(firstname,lastname):
  print(firstname,lastname)
students(firstname='lakshmi',lastname='durga')
students(firstname='hello',lastname='haiii')
# Out:
# lakshmi durga
# hello haiii

# %% [markdown]
# # Arbitary Argument

# %%
def my_function(*kids):
  print("The Youngest child is" +kids[2])
my_function("jithu","akshayy","goutham")
# Out:
# The Youngest child isgoutham

# %%
def my_function(*argv):
  for x in argv:
    print(x)
my_function('hai','welcome','to','ipcs')
# Out:
# hai
# welcome
# to
# ipcs

# %%
def my_function(**student):
  print("His first name"+student["fname"])
my_function(fname="Goutham",lname="Akshayy")
# Out:
# His first nameGoutham

# %%
def my_fun(**kwargs):
  for key,value in kwargs.items():
    print("%s == %s"%(key,value))
my_fun(first='welcome',mid="for",last="class")
# Out:
# first == welcome
# mid == for
# last == class

# %%
def my_fun(country="Norway"):
  print("I am from"+country)
my_fun("America")
my_fun("india")
my_fun("canada")
my_fun("qatar")
# Out:
# I am fromAmerica
# I am fromindia
# I am fromcanada
# I am fromqatar

# %%
def my_fun(xyz):
  for x in (xyz):
    print(x)
fruits=["apple","kiwi","litchi","grapes","mango"]
my_fun(fruits)
# Out:
# apple
# kiwi
# litchi
# grapes
# mango

# %% [markdown]
# # Return value

# %%
def square_value(num):
  return num**2
print(square_value(2))
print(square_value(7))
# Out:
# 4
# 49

# %%
def my_fun(x):
  x[0]=30
lst=[8,23,45,67]
my_fun(lst)
print(lst)
# Out:
# [30, 23, 45, 67]

# %%
def f1():
  s ='I love python'
  def f2():
    print(s)
  f2()
f1()
# Out:
# I love python

# %% [markdown]
# # python lambda

# %%
string='hello python'
print(lambda string:string)
# Out:
# <function <lambda> at 0x7d9c738f4c20>

# %%
a="hello python"
(lambda a:print(a))(a)
# Out:
# hello python

# %%
def cube(y):
  return y*y*y;
g=lambda x:x*x*x
print(g(7))
print(cube(5))
# Out:
# 343
# 125

# %%
def power(n):
  return lambda a:a**n
base=power(2)
print("Now power is set to 2")
print("6 powerof2=",base(6))
base=power(5)
print("Now power is set to 5")
print("8 power of 5=",base(8))
# Out:
# Now power is set to 2
# 6 powerof2= 36
# Now power is set to 5
# 8 power of 5= 32768

# %%
a=[100,2,5,60,40,56,35]
filtered=filter(lambda x:x%2==0,a)
print(list(filtered))
# Out:
# [100, 2, 60, 40, 56]

# %%
a=[9,87,2,47,67]
maped=map(lambda x:x%2==0,a)
print(list(maped))
# Out:
# [False, False, True, False, False]

# %%
def myfunction():
  print(s)
s="I love python"
myfunction()
# Out:
# I love python

# %%
def myfunction():
  s="me too"
  print(s)
s="I love python"
myfunction()
print(s)
# Out:
# me too
# I love python

# %%
a=1
def f():
  print('inside f():',a)
def g():
   a=2
   print('inside g():',g)
def h():
  global a
  a=3
  print('inside h():',a)
print('global:',a)
f()
print('global:',a)
h()
print('global:',a)
# Out:
# global: 1
# inside f(): 1
# global: 1
# inside h(): 3
# global: 3

# %% [markdown]
# # First class functions

# %% [markdown]
# Functions are objects

# %%
def shout(text):
  return text.upper()
print(shout('Hello'))
yell=shout
print(yell('Hello'))
# Out:
# HELLO
# HELLO

# %% [markdown]
# Functions can be passed as argument to other functions

# %%
def shout(text):
  return text.lower()
def whisper(text):
  return text.upper()
def greet(func):
  greeting=func("""Hi,I am created by a function passed as a argument.""")
  print(greeting)
greet(shout)
greet(whisper)
# Out:
# hi,i am created by a function passed as a argument.
# HI,I AM CREATED BY A FUNCTION PASSED AS A ARGUMENT.

# %% [markdown]
# Function can return another function

# %%
def create_adder(x):
  def adder(y):
    return x+y
  return adder
add_15=create_adder(15)
print(add_15(20))
# Out:
# 35

# %% [markdown]
# # Recursive Function

# %%
def calc_factorial(x):
  if x==1:
    return 1
  else:
    return(x*calc_factorial(x-1))
num=5
print("The factorial of",num,"is",calc_factorial(num))
# Out:
# The factorial of 5 is 120

# %% [markdown]
# # Functions questions

# %% [markdown]
# Write a function to print "Hello World".

# %%
def hello():
  print("Hello world")
hello()
# Out:
# Hello world

# %% [markdown]
# Write a function that takes two numbers and returns their sum.

# %%
def add(a,b):
  print(a+b)
add(4,8)
# Out:
# 12

# %% [markdown]
# Write a function to find the square of a number.

# %%
def square(a):
  print(a**a)
square(2)
# Out:
# 4

# %% [markdown]
# Write a function to calculate the area of a rectangle.

# %%
def area(l,b):
  print(l*b)
area(5,2)
# Out:
# 10

# %% [markdown]
# Write a function to check whether a number is even or odd.

# %%
def evenorodd(x):
  if(x%2==0):
    print("even")
  else:
    print("odd")
evenorodd(54)
# Out:
# even

# %% [markdown]
# Write a function to find the largest of two numbers.

# %%
def largest(a,b):
  if a>b:
    print("a is greater")
  else:
    print("b is greater")
largest(3,5)
# Out:
# b is greater

# %% [markdown]
# Write a function to print the multiplication table of a given number.

# %%
def multiplication(x):
  for i in range(1,11):
    print(i,"x",x,"=",i*x)
multiplication(5)
# Out:
# 1 x 5 = 5
# 2 x 5 = 10
# 3 x 5 = 15
# 4 x 5 = 20
# 5 x 5 = 25
# 6 x 5 = 30
# 7 x 5 = 35
# 8 x 5 = 40
# 9 x 5 = 45
# 10 x 5 = 50

# %% [markdown]
# Write a function that returns the factorial of a number.

# %%
def factorial(n):
  fact=1
  for i in range(1,n+1):
    fact*=1
  print(factorial)
factorial(5)
# Out:
# <function factorial at 0x7fc2634ae340>

# %% [markdown]
# Write a function to count vowels in a string.

# %%
def vowels():
  text="hello world"
  count=0
  x="aeiouAEIOU"
  for x in text:
    if x in "aeiouAEIOU":
      count+=1
  print("vowels=",count)
vowels()
# Out:
# vowels= 3

# %% [markdown]
# Write a function to reverse a string.

# %%
def text():
  text="lakshmi"
  reverse=" "
  for i in text:
    reverse=i+reverse
  print(reverse)
text()
# Out:
# imhskal

# %% [markdown]
# Write a function that returns the sum of elements in a list.

# %%
def sum():
  my_list=[8,8,4]
  total_sum = 0
  for x in my_list:
    total_sum += x
  print(sum)
sum()
# Out:
# [8, 8, 4]

# %% [markdown]
# Write a function to count uppercase and lowercase characters in a string.

# %%
a = "Hello World"
u = 0
l = 0
for i in a:
    if i.isupper():
        u += 1
    elif i.islower():
        l += 1
print("Uppercase:", u)
print("Lowercase:", l)
# Out:
# Uppercase: 2
# Lowercase: 8

# %% [markdown]
# Write a function that accepts a list of marks and returns the grade of the student.

# %%
x=int(input("enter the number"))
def grades():
  if x>90:
    print("A+")
  elif x>80:
    print("A")
  elif x>70:
   print("B+")
  elif x>60:
   print("c")
  elif x>50:
   print("D")
  elif x>40:
   print("c")
  else:
    print("fail")
print(grades)
grades()
# Out:
# enter the number67
# <function grades at 0x7dd076083060>
# c

# %% [markdown]
# write a function to merge two lists without using + operator

# %%
def merge(a, b):
    for i in b:
        a.append(i)
    return a
print(merge([1,2,3], [4,5,6]))
# Out:
# [1, 2, 3, 4, 5, 6]

# %% [markdown]
# Write a function to check if a number is prime.

# %%
def prime(num):
  if num <= 1:
      return False
  for i in range(2, num):
      if num % i == 0:
        return true
        return false
print(prime)
# Out:
# <function prime at 0x7dd055637ec0>

# %% [markdown]
# Write a function to compute the area of circle, square & rectangle using menu-driven choice.

# %%
def area(l,b):
  return l*b
l=int(input("enter the length"))
b=int(input("enter the breadth"))
print(area(l,b))
# Out:
# enter the length5
# enter the breadth5
# 25

# %%
def area_circle(r):
  return 3.14*r*r
r=int(input("enter the radius"))
print(area_circle(r))
# Out:
# enter the radius4
# 50.24

# %%
def area_square(s):
  return s*s
s=int(input("enter the number of side1"))
print(area_square(s))
# Out:
# enter the number of side17
# 49

# %% [markdown]
# Write a function to find the sum of digits of a number

# %%
def sum_digits(n):
  result = 0
  while n > 0:
      digit = n % 10
      result = result + digit
      n = n // 10
  return(result)
n= int(input("enter the number"))
print(sum_digits(n))
# Out:
# enter the number1413
# 9

# %%
my_list = [10,20,30,60,30]
print("Original list:",my_list)

print("Count of 30:",my_list.count(30))

my_list.append(70)
print("After append:",my_list)
my_list.remove(10)
print("After remove:",my_list)

print("Index of 60:",my_list.index(60))

my_list.reverse()
print("After reverse:",my_list)

my_list.sort()
print("After sort:",my_list)
# Out:
# Original list: [10, 20, 30, 60, 30]
# Count of 30: 2
# After append: [10, 20, 30, 60, 30, 70]
# After remove: [20, 30, 60, 30, 70]
# Index of 60: 2
# After reverse: [70, 30, 60, 30, 20]
# After sort: [20, 30, 30, 60, 70]

# %% [markdown]
# # Iterartor

# %%
mytuple=("apple","banana","cherry")
myit=iter(mytuple)
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# cherry

# %%
mystr="Mango"
myit=iter(mystr)
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# M
# a
# n
# g
# o

# %%
mytuple=("litchi","guva","mango")
for x in mytuple:
  print(x)
# Out:
# litchi
# guva
# mango

# %%
class MyNumbers:
  def __iter__(self):
    self.a=1
    return self
  def __next__(self):
    x=self.a
    self.a+=1
    return x
myclass=MyNumbers()
myiter=iter(myclass)
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
print(next(myiter))
# Out:
# 1
# 2
# 3
# 4
# 5
# 6

# %% [markdown]
# Generator

# %%
def greeting():
  print('Hi!')
  yield 1
  print('How are you?')
  yield 2
  print('Are you there?')
  yield 3
messenger=greeting()
result=next(messenger)
print(result)
result=next(messenger)
print(result)
result=next(messenger)
print(result)
# Out:
# Hi!
# 1
# How are you?
# 2
# Are you there?
# 3

# %% [markdown]
# # Thread

# %%
import threading
def task():
  print("Thread running")
thread=threading.Thread(target=task)
thread.start()
thread.join()
# Out:
# Thread running

# %%
import threading
def task1():
  print("Task 1")
def task2():
  print("Task 2")
t1=threading.Thread(target=task1)
t2=threading.Thread(target=task2)
t1.start()
t2.start()
t1.join()
t2.join()
# Out:
# Task 1
# Task 2

# %%
import threading
def print_numbers():
  for i in range(6):
    print(i)
thread=threading.Thread(target=print_numbers)
thread.start()
thread.join()
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %%
import threading
import time
def download_file(file):
  print(f"downloading{file}...")
  time.sleep(2)
  print(f"{file} downloaded")
file=["file1.txt","file2.txt","file3.txt"]
threads=[threading.Thread(target=download_file,args=(f,))for f in file]
for t in threads:
  t.start()
for t in threads:
  t.join()
# Out:
# downloadingfile1.txt...
# downloadingfile2.txt...
# downloadingfile3.txt...
# file1.txt downloaded
# file2.txt downloaded
# file3.txt downloaded

# %%
import threading
def greet(name):
  print(f"Hello,{name}!")
thread=threading.Thread(target=greet,args=("lakshmi",))
thread.start()
thread.join()
# Out:
# Hello,lakshmi!

# %%
import threading
import time
def chef_work():
  for i in range(5):
    print(f"chef:preparing dish{i+1}...")
    time.sleep(2)
    if i==2:
      print("chef:callng assistant to wash utensil.")
      time.sleep(1)
      assistant_thread=threading.Thread(target=assistant_work)
      assistant_thread.start()
      assistant_thread.join()
      print("chef:Assistant done.Resuming dish prepartion.")
  print("chef:All dishes are prepared.")
def assistant_work():
  for j in range(3):
    print(f"Assistant:washing utensil{j+1}...")
    time.sleep(2)
print("Assistant:All utensils are clean.")
chef_thread=threading.Thread(target=chef_work)
chef_thread.start()
chef_thread.join()
print("kitchen:All work completed.")
# Out:
# Assistant:All utensils are clean.
# chef:preparing dish1...
# chef:preparing dish2...
# chef:preparing dish3...
# chef:callng assistant to wash utensil.
# Assistant:washing utensil1...
# Assistant:washing utensil2...
# Assistant:washing utensil3...
# chef:Assistant done.Resuming dish prepartion.
# chef:preparing dish4...
# chef:preparing dish5...
# chef:All dishes are prepared.
# kitchen:All work completed.

# %% [markdown]
# Write a Python program using threading to simulate music playback and lyrics downloading:
#
# Music playback runs in one thread for 5 seconds, printing a message each second. During the 3rd second, a separate thread starts to simulate downloading lyrics, which takes 3 seconds. Ensure the music playback waits for the lyrics to finish downloading before continuing.
#
# Output
#
# Music Player: Starting music playback. Music Player: Playing music... 1 seconds Music Player: Playing music... 2 seconds Music Player: Playing music... 3 seconds Music Player: Downloading lyrics in the background. Downloading lyrics... 1 seconds Downloading lyrics... 2 seconds Downloading lyrics... 3 seconds Lyrics download completed. Music Player: Lyrics downloaded. Music Player: Playing music... 4 seconds Music Player: Playing music... 5 seconds Music Player: Playback ended

# %%
import threading
import time
def Music_player():
   print(f"Music Player: Starting music playback.")
   for i in range(5):

    print(f"Music player:music playing{i+1}...seconds")
    time.sleep(2)
    if i==2:
        print(f"Music Player: Downloading lyrics in the background.")
        time.sleep(3)
        download_thread= threading.Thread(target=download_lyrics)
        download_thread.start()
        download_thread.join()
        print("Music player:Lyrics download completed.")
def download_lyrics():
  for x in range(3):
    print(f"Music player:lyrics downloaded{x+1}...")

Music_thread=threading.Thread(target=Music_player)
Music_thread.start()
Music_thread.join()
print("Music player:playback ended")
# Out:
# Music Player: Starting music playback.
# Music player:music playing1...seconds
# Music player:music playing2...seconds
# Music player:music playing3...seconds
# Music Player: Downloading lyrics in the background.
# Music player:lyrics downloaded1...
# Music player:lyrics downloaded2...
# Music player:lyrics downloaded3...
# Music player:Lyrics download completed.
# Music player:music playing4...seconds
# Music player:music playing5...seconds
# Music player:playback ended
